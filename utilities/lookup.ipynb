# %%
import pandas as pd
import lookup
import timeit
# Out:
# UsageError: Line magic function `%reload` not found.

# %%
s, g = lookup.get_lookups()
# Out:
# Gathering sources: 100%|██████████| 3/3 [00:08<00:00,  2.95s/it]

# %%
lookup.save_lookup(s, g)

# %%
s2, g2 = lookup.load_lookup('symbol_lookup_2020_06.csv', 'geneid_lookup_2020_06.csv')

# %%
for k, v in s.items():
    if k not in s2 or s2[k] != v:
        print(k, v)
# Out:
# C100857961
# EMC4 EMC4
# LOC100857964 LOC100857964
# LOC100857965 LOC100857965
# LOC100857966 LOC100857966
# GM2A GM2A
# ONECUT2 ONECUT2
# LOC100857975 LOC100857975
# S1PR2 S1PR2
# LOC100857977 LOC100857977
# GPR35L GPR35L
# TMEM35B TMEM35B
# ZMYM6NB TMEM35B
# HEATR8L4 HEATR8L4
# LOC100857987 LOC100857987
# LOC100857990 LOC100857990
# LOC100857993 LOC100857993
# LOC100857996 LOC100857996
# FANCM FANCM
# PYGO2 PYGO2
# DDX23 DDX23
# TBX21 TBX21
# TTC31 TTC31
# SELENOH SELENOH
# C11orf31 SELENOH
# C5H11orf31 SELENOH
# SELH SELENOH
# RP11-400G3.5 RP11-400G3.5
# CYP2C21L RP11-400G3.5
# A2ML4 A2ML4
# LOC100858012 LOC100858012
# EMILIN1 EMILIN1
# LOC100858017 LOC100858017
# LOC100858018 LOC100858018
# PIGF PIGF
# NPS NPS
# PCDHB2 PCDHB2
# LLGL1 LLGL1
# SMIM12 SMIM12
# LOC100858030 LOC100858030
# LOC100858031 LOC100858031
# LOC100858032 LOC100858032
# ENDOU ENDOU
# NACC1 NACC1
# LOC100858040 LOC100858040
# YPEL4 YPEL4
# ZNF551 ZNF551
# LOC100858046 LOC100858046
# ZNF79L1 ZNF79L1
# HIST1H46L2 HIST1H46L2
# KIAA1211L CRACDL
# HSDL2 HSDL2
# SNPH SNPH
# LOC100858059 LOC100858059
# TBX15L LOC100858059
# CLCF1 CLCF1
# OR14J1L64 OR14J1L64
# LOC100858063 LOC100858063
# LRG1 LRG1
# KCNA6 KCNA6
# LOC100858068 LOC100858068
# LOC100858069 LOC100858069
# CHRAC1 CHRAC1
# RNF150 RNF150
# UBE2L6 UBE2L6
# STOX1 STOX1
# RGSL1 RGSL1
# RGSL2 RGSL1
# LOC100858078 LOC100858078
# LOC100858081 LOC100858081
# LOC100858082 LOC100858082
# LOC100858083 LOC100858083
# LOC100858084 LOC100858084
# CMESO2 MESP2
# cMeso-1 MESP2
# R3HDML R3HDML
# C19orf70 MICOS13
# C28H19orf70 C19orf70
# SLC6A18 SLC6A18
# AKAP7L AKAP7L
# PRPF39 PRPF39
# HEATR8L5 HEATR8L5
# LOC100858099 LOC100858099
# LOC100858100 LOC100858100
# TMEM74 TMEM74
# AGO2 AGO2
# BTBD19 BTBD19
# LOC100858106 LOC100858106
# KCNN3 KCNN3
# PAF1 PAF1
# LOC100858111 LOC100858111
# DNAH8 DNAH8
# ZNF710 ZNF710
# CYBC1C8L CYBC1C8L
# MEGF9 MEGF9
# MEGF9L MEGF9
# FFAR2L6 FFAR2L6
# LOC100858118 LOC100858118
# OR14J1L7 OR14J1L7
# CXorf23 BCLAF3
# BCLAF3 BCLAF3
# KCNH2 KCNH2
# ZC3H10 ZC3H10
# LHFPL3 LHFPL3
# LOC100858128 LOC100858128
# TMEM8AL LOC100858128
# LOC100858129 LOC100858129
# CBARP CBARP
# LOC100858131 LOC100858131
# PCDHB4L2 PCDHB4L2
# SYCN SYCN
# NME7 NME7
# GDPGP1 GDPGP1
# LOC100858152 LOC100858152
# PPP1CA PPP1CA
# LOC100858158 LOC100858158
# AOC1 AOC1
# ABP1 DBNL
# SNAPIN SNAPIN
# C17orf53 HROB
# LOC100858168 LOC100858168
# XKR4 XKR4
# LOC100858172 LOC100858172
# ALPK1 ALPK1
# NEUROG3 NEUROG3
# LOC100858177 LOC100858177
# LOC100858179 LOC100858179
# OR14J1L50 OR14J1L50
# LOC100858183 LOC100858183
# LOC100858187 LOC100858187
# MAP3K6 MAP3K6
# LOC100858194 LOC100858194
# LOC100858196 LOC100858196
# CCR10 ACKR4
# PBDC1 PBDC1
# EXT1 EXT1
# exostosin-1 EXT1
# exostosin-1-like EXT1
# ARL14EPL ARL14EPL
# CTD-2287O16.3 ARL14EPL
# SARS2 SARS2
# CTC-360G5.8 SARS2
# ATP5G2 ATP5MC2
# ATP5MC2 ATP5MC2
# MRPL55 MRPL55
# LOC100858220 LOC100858220
# MARVELD1 MARVELD1
# THEM4 THEM4
# LOC100858224 LOC100858224
# MIEN1 MIEN1
# LOC100858226 LOC100858226
# IGSF1L6 LOC100858226
# LOC100858227 LOC100858227
# OR14A16L4 OR14A16L4
# SLC6A13 SLC6A13
# GAT-2 SLC6A13
# GAT2 SLC6A13
# GAT3 SLC6A13
# UPF3B UPF3B
# DENND2C DENND2C
# MADCAM1 MADCAM1
# MROH2B1 MROH2B1
# HEATR7B2 MROH2B
# PYM1 PYM1
# WIBG PYM1
# LOC100858250 LOC100858250
# LOC100858252 LOC100858252
# LOC100858253 LOC100858253
# LOC100858256 LOC100858256
# S100A1 S100A1
# LOC100858259 LOC100858259
# LOC100858260 LOC100858260
# ST3GAL2L LOC100858260
# LOC100858262 LOC100858262
# GPR18 GPR18
# FAF USP9X
# LOC100858271 LOC100858271
# LOC100858273 LOC100858273
# TESK2 TESK2
# ADAMTS18 ADAMTS18
# LOC100858279 LOC100858279
# OTUD5 OTUD5
# CLC2EL4 CLC2EL4
# LOC100858283 LOC100858283
# LOC100858284 LOC100858284
# LOC100858291 LOC100858291
# LOC100858293 LOC100858293
# LOC100858294 LOC100858294
# LOC100858295 LOC100858295
# RPL22L1 RPL22L1
# CPNE1L CPNE1L
# KSR2 KSR2
# KRT75L4 KRT75L4
# K9LC1 KRT75L4
# NAPA NAPSA
# LOC100858306 LOC100858306
# LOC100858307 LOC100858307
# LOC100858311 LOC100858311
# RUNDC3A RUNDC3A
# LOC100858315 LOC100858315
# AMPD2 AMPD2
# LOC100858317 LOC100858317
# HIST1H4I H4C9
# HIST1H46L4 HIST1H4I
# EYS EYS
# LOC100858322 LOC100858322
# FAM163B FAM163B
# RAB2B RAB2B
# LOC100858331 LOC100858331
# LOC100858332 LOC100858332
# C16orf71 C16orf71
# FGF22 FGF22
# OR14J1L130 OR14J1L130
# CATH3 CATH3
# CATHL3 CATH3
# LOC100858347 LOC100858347
# LOC100858348 LOC100858348
# EIF4B EIF4B
# ECH1 ECH1
# OR14J1L12 OR14J1L12
# HIST1H103 HIST1H103
# HIST1H1B H1-5
# LOC100858355 LOC100858355
# BBIP1 BBIP1
# LOC100858360 LOC100858360
# HSD11B2 HSD11B2
# SLC2A4RG SLC2A4RG
# HAPLN4 HAPLN4
# NOL6 NOL6
# HOXC6 HOXC6
# HOXC-6 HOXC6
# LOC100858369 LOC100858369
# CHIR-AB-852 LOC100858369
# OR14J1L5 OR14J1L5
# LOC100858373 LOC100858373
# LOC100858378 LOC100858378
# OR14J1L6 OR14J1L6
# LOC100858381 LOC100858381
# PFDN2 PFDN2
# LOC100858384 LOC100858384
# LOC100858385 LOC100858385
# CHIR2D-681 LOC100858385
# CHIR2D-688 LOC100858385
# CHIR2D-735 LOC100858385
# CHIR2D-761 LOC100858385
# CHIR2D-769 LOC100858385
# CHIR2D-796 LOC100858385
# CHIR2D-943 LOC100858385
# CHIR2D-993 LOC100858385
# LOC100858386 LOC100858386
# LOC100858387 LOC100858387
# LOC100858388 LOC100858388
# OR14J1L65 OR14J1L65
# LOC100858393 LOC100858393
# LRRC55 LRRC55
# LOC100858395 LOC100858395
# CNOT1 CNOT1
# NR2C2AP NR2C2AP
# MRPL9 MRPL9
# LOC100858403 LOC100858403
# PLTGP6L2 LOC100858403
# HOXA5 HOXA5
# HOX1.3 HOXA5
# HOX1C HOXA5
# EIF4EBP3 EIF4EBP3
# DECR2 DECR2
# PLPPR3 PLPPR3
# LPPR3 PLPPR3
# LOC100858411 LOC100858411
# LILRA2L1 LOC100858411
# CATHB1 CATHB1
# CATH-B1 CATHB1
# cathelicidin-B1 CATHB1
# SPOCK2 SPOCK2
# NFKBIB NFKBIB
# FLT3 FLT3
# IL34 IL34
# LOC100858426 LOC100858426
# BRD3OS BRD3OS
# LOC100858427 LOC100858427
# TMEM221 TMEM221
# CTD-2521M24.10 TMEM221
# SPRYD3 SPRYD3
# FFAR2L4 FFAR2L4
# LOC100858433 LOC100858433
# LOC100858436 LOC100858436
# KRT17 KRT17
# ARID3A ARID3A
# LOC100858444 LOC100858444
# OTOS OTOS
# ZNF708L ZNF708L
# LOC100858451 LOC100858451
# LOC100858452 LOC100858452
# SCRT1 SCRT1
# ODF3F ODF3F
# LOC100858456 LOC100858456
# OR14J1L4 OR14J1L4
# MYRF MYRF
# MYRFL MYRFL
# HIST1H2A4L1 HIST1H2A4L1
# SYTL3 SYTL3
# DTHD1 DTHD1
# PDYN PDYN
# SNORD12C SNORD12C
# SNORD12 SNORD12
# LOC100858470 LOC100858470
# PLPP2 PLPP2
# PPAP2C PLPP2
# LMAN2L LMAN2L
# LOC100858474 LOC100858474
# LOC100858475 LOC100858475
# ZNF624 ZNF624
# CTD-2331H12.8 ZNF624
# OR14J1L49 OR14J1L49
# TRAPPC5 TRAPPC5
# UEVLD UEVLD
# CARTPT CARTPT
# CART CARTPT
# LOC100858489 LOC100858489
# LOC100858490 LOC100858490
# LOC100858491 LOC100858491
# LOC100858494 LOC100858494
# LOC100858495 LOC100858495
# LOC100858497 LOC100858497
# LOC100858500 LOC100858500
# FAM131A FAM131A
# LOC100858504 LOC100858504
# LOC100858505 LOC100858505
# TLE2L LOC100858505
# LOC100858506 LOC100858506
# LOC100858507 LOC100858507
# SUN3L1 LOC100858507
# TRMT112 TRMT112
# LOC100858509 LOC100858509
# LOC100858511 LOC100858511
# PTPN23 PTPN23
# CLRN2 CLRN2
# SP9 SP9
# DOP1B DOP1B
# AXDND1 AXDND1
# C1orf125 AXDND1
# MOGL6 MOGL6
# LOC100858531 LOC100858531
# MRPL49 MRPL49
# HOXC5 HOXC5
# LOC100858535 LOC100858535
# AES TLE5
# LOC100858543 LOC100858543
# ZNF541 ZNF541
# ABHD14A ABHD14A
# MFAP2 MFAP2
# DMRT2 DMRT2
# Terra Dmrt2
# LOC100858559 LOC100858559
# EXOSC8 EXOSC8
# ADGRD2 ADGRD2
# GPR144 ADGRD2
# UBE2Q1 UBE2Q1
# CTSW CTSW
# OR14A16L28 OR14A16L28
# LOC100858569 LOC100858569
# LOC100858570 LOC100858570
# LOC100858573 LOC100858573
# CLK1 COLEC11
# ROBO3 ROBO3
# LOC100858579 LOC100858579
# LOC100858580 LOC100858580
# MHCIA5 MHCIA5
# RAB25 RAB25
# MED1L MED1L
# OTX1 OTX1
# WDR55 WDR55
# SORT1 SORT1
# sortilin SORT1
# LOC100858593 LOC100858593
# LOC100858599 LOC100858599
# LOC100858601 LOC100858601
# ADCY10L8 ADCY10L8
# LOC100858604 LOC100858604
# LOC100858605 LOC100858605
# ZNF229L ZNF229L
# H2B.2 H2BC17
# H2B/n H2BC17
# H2BFN H2BC17
# HIST1H2B7L3 HIST1H2BO
# dJ193B12.2 H2BC17
# CRELD1 CRELD1
# NT5DC4 NT5DC4
# OR14J1L66 OR14J1L66
# PCGF1 PCGF1
# CLC2LL CLC2LL
# WDR74 WDR74
# KCNE5 KCNE5
# CLMN CLMN
# LOC100858626 LOC100858626
# ZFAND2B ZFAND2B
# PIGB PIGB
# LOC100858629 LOC100858629
# FJX1 FJX1
# fj FJX1
# NUDT21 NUDT21
# SPRY4L SPRY4L
# CLPB CLPB
# LOC100858640 LOC100858640
# LOC100858645 LOC100858645
# LOC100858646 LOC100858646
# LOC100858647 LOC100858647
# LOC100858649 LOC100858649
# FAM110A FAM110A
# CAMK2N1 CAMK2N1
# FOXP4 FOXP4
# FOXP4L FOXP4
# DHX58 DHX58
# LGP2 DHX58
# ZNF7L ZNF7L
# ILF3 ILF3
# LOC100858656 LOC100858656
# LILRB5L LOC100858656
# LILRB5L2 LOC100858656
# LOC100858664 LOC100858664
# 2KTGRL LOC100858664
# LOC100858665 LOC100858665
# WNT2L WNT2L
# BZFP2 BZFP2
# LOC100858675 LOC100858675
# MAX MAX
# LOC100858677 LOC100858677
# LOC100858678 LOC100858678
# HIST1H3H H3C10
# LOC100858682 LOC100858682
# TUBGCP5 TUBGCP5
# LOC100858684 LOC100858684
# LOC100858686 LOC100858686
# LOC100858687 LOC100858687
# LOC100858688 LOC100858688
# MRPL43 MRPL43
# CCDC71 CCDC71
# SRXN1 SRXN1
# sulfiredoxin-1 SRXN1
# ARID3C ARID3C
# GR42LP3 GR42LP3
# OR14J1L133 OR14J1L133
# RRP36 RRP36
# AvBD14 AvBD14
# GAL14 AvBD14
# Gal-14 AvBD14
# LSMEM2 LSMEM2
# LOC100858705 LOC100858705
# CPXM1 CPXM1
# PRDM14 PRDM14
# LOC100858710 LOC100858710
# THT2L THT2L
# TMEM256 TMEM256
# LOC100858719 LOC100858719
# ACACB2L LOC100858719
# OR14J1L110 OR14J1L110
# USP19 USP19
# LOC100858728 LOC100858728
# MPND MPND
# CRLF1 CRLF1
# STAT2 STAT2
# MHCIA8 MHCIA8
# ZBTB39 ZBTB39
# MORN3 MORN3
# LOC100858737 LOC100858737
# PNMT PEMT
# LOC100858739 LOC100858739
# LOC100858742 LOC100858742
# C18ORF25 LOC100858742
# NXPH4 NXPH4
# LOC100858744 LOC100858744
# LOC100858746 LOC100858746
# LOC100858747 LOC100858747
# TRIM10 TRIM10
# B-BTN2 TRIM10
# BTN2 TRIM10
# SLA2 SLA2
# FCER2 FCER2
# KEAP1 KEAP1
# LOC100858753 LOC100858753
# NOS3 NANOS3
# LOC100858755 LOC100858755
# LOC100858757 LOC100858757
# QRICH1 QRICH1
# LOC100858759 LOC100858759
# LOC100858760 LOC100858760
# LOC100858761 LOC100858761
# LOC100858762 LOC100858762
# IFNAL2 LOC100858762
# FAM214B FAM214B
# LOC100858769 LOC100858769
# LOC100858772 LOC100858772
# ZNF737L ZNF737L
# LOC100858775 LOC100858775
# NEDD8 NEDD8
# LOC100858777 LOC100858777
# BLEC3 BLEC3
# PROCA1 PROCA1
# MBLAC1 MBLAC1
# LOC100858784 LOC100858784
# LOC100858786 LOC100858786
# OR14A16L5 OR14A16L5
# LOC100858788 LOC100858788
# LMO1 LMO1
# LMO-1 LMO1
# rhombotin-1 LMO1
# MRPL40 MRPL40
# SESN2 SESN2
# LOC100858797 LOC100858797
# NMRK2 NMRK2
# UNC13B UNC13B
# LOC100858800 LOC100858800
# C20orf27 C20orf27
# OR14J1L67 OR14J1L67
# LRRC3C LRRC3C
# LOC100858808 LOC100858808
# LOC100858809 LOC100858809
# LOC100858812 LOC100858812
# MOGL5 MOGL5
# LOC100858814 LOC100858814
# LOC100858818 LOC100858818
# LOC100858819 LOC100858819
# LOC100858821 LOC100858821
# LOC100858822 LOC100858822
# TLR2L TLR2L
# PRKAR2A PRKAR2A
# MORC1 MORC1
# MORC2 MORC2
# ANKRD55 ANKRD55
# ACY1 ACY1
# PCDHGA2L PCDHGA2L
# PIM1 LONP1
# CLC2BL1 CLC2BL1
# APOA2 LPAL2
# LOC100858845 LOC100858845
# EFCAB7 EFCAB7
# MIF4GD MIF4GD
# RAB34 RAB34
# ZNF367 ZNF367
# LRRC14 LRRC14
# LOC100858859 LOC100858859
# LOC100858860 LOC100858860
# C19orf25 C19orf25
# C28H19orf25 C19orf25
# LOC100858865 LOC100858865
# SLC39A5 SLC39A5
# OR14A16L47 OR14A16L47
# LOC100858869 LOC100858869
# DUSP23 PTPMT1
# LOC100858877 LOC100858877
# TTYH1 TTYH1
# TTYH2TTYH2
# CCS CCS
# OR14J1L25 OR14J1L25
# LOC100858884 LOC100858884
# OR14J1L26 OR14J1L26
# CLDN22 CLDN22
# CCDC149 CCDC149
# BPTF BPTF
# FAM43B FAM43B
# TCEA3 TCEA3
# C19orf45 TEX45
# C28H19orf45 C19orf45
# CTD-2207O23.12 C19orf45
# ZNF3L2 ZNF3L2
# LOC100858902 LOC100858902
# LOC100858908 LOC100858908
# TRMT2B TRMT2B
# TRMT TRMU
# GPR182 GPR182
# LOC100858911 LOC100858911
# CTNNAL1 CTNNAL1
# SMAP1 SMAP1
# LOC100858919 LOC100858919
# SYPL2 SYPL2
# LOC100858925 LOC100858925
# HRH1 DHX34
# LOC100858929 LOC100858929
# LOC100858930 LOC100858930
# EXOSC5 EXOSC5
# ZNF135L3 ZNF135L3
# CNPY2 CNPY2
# LOC100858934 LOC100858934
# LOC100858935 LOC100858935
# PAQR9 PAQR9
# LOC100858937 LOC100858937
# ARHGDIG ARHGDIG
# DHRS13 DHRS13
# LOC100858941 LOC100858941
# LOC100858942 LOC100858942
# HLA-A HLA-A
# LOC100858944 LOC100858944
# GPR34L LOC100858944
# ZNF551L2 ZNF551L2
# CACNA2D4 CACNA2D4
# PHYHD1 PHYHD1
# LOC100858953 LOC100858953
# LOC100858954 LOC100858954
# OR14A16L39 OR14A16L39
# PTCRA PTCRA
# LOC100858962 LOC100858962
# LOC100858963 LOC100858963
# IL23A IL23A
# NRN1L NRN1L
# GTF2H2 GTF2H2
# LOC100858973 LOC100858973
# GNG7 GNG7
# LOC100858977 LOC100858977
# LOC100858978 LOC100858978
# COL10A1 COL10A1
# LOC100858984 LOC100858984
# GPR61 GPR61
# PREB PREB
# OR14J1L117 OR14J1L117
# HSPBP1 HSPBP1
# CA13 CA13
# CNPY3 CNPY3
# LOC100858995 LOC100858995
# DIRAS1 DIRAS1
# ADAMTS4 ADAMTS4
# USP39 USP39
# LOC100859001 LOC100859001
# LOC100859002 LOC100859002
# ARHGAP36 ARHGAP36
# RASSF10 RASSF10
# HLA-F10AL2 HLA-F10AL2
# MMAB MMAB
# NR2F6 NR2F6
# LOC100859016 LOC100859016
# LOC100859020 LOC100859020
# LOC100859022 LOC100859022
# AHDC1 AHDC1
# FBXL12 FBXL12
# GBA3 GBA3
# LOC100859029 LOC100859029
# FOXB1 FOXB1
# LOC100859032 LOC100859032
# IFNAL6 LOC100859032
# LOC100859033 LOC100859033
# ZNF79L2 ZNF79L2
# LOC100859035 LOC100859035
# LOC100859036 LOC100859036
# NUR2L NUR2L
# neurabin-2 NUR2L
# LOC100859039 LOC100859039
# IL17C IL17C
# LOC100859041 LOC100859041
# APBB1 APBB1
# CCDC102B CCDC102B
# CLEC5A CLEC5A
# LOC100859052 LOC100859052
# LOC100859053 LOC100859053
# LOC100859054 LOC100859054
# LOC100859055 LOC100859055
# BRD4L BRD4
# LOC100859057 LOC100859057
# OR14A16L11 OR14A16L11
# LOC100859062 LOC100859062
# LOC100859063 LOC100859063
# LOC100859064 LOC100859064
# LOC100859067 LOC100859067
# NELFE NELFE
# RDBP NELFE
# LOC100859072 LOC100859072
# ODF3J ODF3J
# ODF3 ODF3
# ODF3B ODF3B
# LOC100859075 LOC100859075
# IGSF1L7 LOC100859075
# LOC100859077 LOC100859077
# ZNHIT3 ZNHIT3
# LOC100859084 LOC100859084
# FFAR2LP FFAR2LP
# LOC100859088 LOC100859088
# NINL NINL
# S100A16 HRNR
# LOC100859096 LOC100859096
# PIWIL2 PIWIL2
# LOC100859100 LOC100859100
# HLA-F10AL3 LOC100859100
# C9orf69 TMEM250
# C17H9orf69 C9orf69
# TMEM250 TMEM250
# B3GNT6 B3GNT6
# LOC100859106 LOC100859106
# STAMBPL1 STAMBPL1
# SYNGR2 SYNGR2
# HINT2Z HINT1
# TSPAN19 TSPAN19
# ATL2 ATL2
# LOC100859119 LOC100859119
# AHNAK2 AHNAK2
# PRX PRX
# LOC100859124 LOC100859124
# GZMM GZMM
# LOC100859125 LOC100859125
# LOC100859127 LOC100859127
# LOC100859129 LOC100859129
# TMPRSS13 TMPRSS13
# RASGRF2 RASGRF2
# PTGES3 PTGES3
# CPGES PTGES3
# TEBP PTGES3
# LOC100859134 LOC100859134
# HLA-F10AL4 LOC100859134
# ZNF665L ZNF665L
# LOC100859136 LOC100859136
# PAX1 PAX1
# GPX-1 PAX1
# Pax-1 Pax1
# TMC6L TMC6L
# LOC100859143 LOC100859143
# LILRB5L1 LOC100859143
# LOC100859144 LOC100859144
# FAM184B FAM184B
# LOC100859148 LOC100859148
# LOC100859149 LOC100859149
# PCSK4 PCSK4
# PIN1 PDZD2
# LOC100859154 LOC100859154
# LOC100859155 LOC100859155
# PCDHB14L1 PCDHB14L1
# LOC100859157 LOC100859157
# LOC100859161 LOC100859161
# ANKRD13B ANKRD13B
# LOC100859173 LOC100859173
# TMEM178A TMEM178A
# LOC100859176 LOC100859176
# GNGT2 GNGT2
# GR42L5 GR42L5
# PRKACA PRKCA
# GPR132 GPR132
# MZB1 MZB1
# LOC100859191 LOC100859191
# DQX1 DQX1
# OR14A16L6 OR14A16L6
# STAT6 STAT6
# MLH3 MLH3
# LOC100859202 LOC100859202
# NEUROD2 NEUROD2
# LOC100859205 LOC100859205
# LOC100859206 LOC100859206
# USP40 USP40
# LOC100859213 LOC100859213
# LOC100859214 LOC100859214
# CCNT1 CCNT1
# OR14J1L14 OR14J1L14
# BCL11BL1 BCL11BL1
# GPR62 GPR62
# LOC100859226 LOC100859226
# LOC100859228 LOC100859228
# ZNF512BL LOC100859228
# LOC100859229 LOC100859229
# LOC100859230 LOC100859230
# LOC100859232 LOC100859232
# LOC100859233 LOC100859233
# TMPRSS5 TMPRSS5
# TMEM252 TMEM252
# LOC100859238 LOC100859238
# RAD23A RAD23A
# LOC100859242 LOC100859242
# LNAATS1L LOC100859242
# OR14J1L68 OR14J1L68
# LOC100859246 LOC100859246
# LOC100859249 LOC100859249
# FRMPD1 FRMPD1
# OR14J1L128 OR14J1L128
# P2RY11 PPAN-P2RY11
# LOC100859258 LOC100859258
# SUMF1 SUMF1
# LOC100859262 LOC100859262
# SGCA SGCA
# alpha-sarcoglycan-like SGCA
# OR14A16L7 OR14A16L7
# ZBTB20 ZBTB20
# LOC100859267 LOC100859267
# LOC100859272 LOC100859272
# WFDC2L LOC100859272
# LOC100859273 LOC100859273
# HUWE1 HUWE1
# LOC100859274 LOC100859274
# LOC100859275 LOC100859275
# LOC100859276 LOC100859276
# CYP4F11 CYP4F11
# CYP4F22 CYP4F22
# CYP4F49 CYP4F11
# FEZF1 FEZF1
# SLITRK5 SLITRK5
# LOC100859281 LOC100859281
# PHLDA3 PHLDA3
# LOC100859284 LOC100859284
# EPN3 EPN3
# SHISA4 SHISA4
# OR14A16L2 OR14A16L2
# ARID3B ARID3B
# LOC100859298 LOC100859298
# MFRP C1QTNF5
# LOC100859300 LOC100859300
# ZNF167L ZNF167L
# LOC100859302 LOC100859302
# OR14J1L15 OR14J1L15
# LOC100859304 LOC100859304
# SPAG8 SPAG8
# CLC2DL1 CLC2DL1
# LOC100859312 LOC100859312
# LOC100859314 LOC100859314
# SPTSSBL SPTSSBL
# ATP2C2 ATP2C2
# RAB37 RAB37
# CD48 CD48
# NDUFA13 NDUFA13
# CTC-260F20.3 NDUFA13
# TAAR2 TAAR3P
# PLXNB3 PLXNB3
# PLXNB1 PLXNB1
# plexin-B1 PLXNB3
# LOC100859327 LOC100859327
# CTXN3 CTXN3
# OR14J1L69 OR14J1L69
# LOC100859330 LOC100859330
# PLTGP6L3 LOC100859330
# LOC100859331 LOC100859331
# PPIL1 PPIL1
# OR14J1L120 OR14J1L120
# C11orf94 C11orf94
# C5H11orf94 C11orf94
# NPR2 NPRL2
# NPR-B NPR2
# ZNF740 ZNF740
# AHR1B AHR1B
# LOC100859348 LOC100859348
# PRICKLE4 PRICKLE4
# TIMM13 TIMM13
# LOC100859353 LOC100859353
# G6PC3 G6PC3
# LOC100859357 LOC100859357
# LOC100859360 LOC100859360
# VEPH1 VEPH1
# EXTL1 EXTL1
# TSEN34 TSEN34
# FFAR2L FFAR2L
# FFAR3a FFAR2L
# OR14J1L41 OR14J1L41
# PRG4 PLPPR2
# PLEKHG4 PLEKHG4
# MHCIA2 MHCIA2
# PFDN5 PFDN5
# PCDHB4L3 PCDHB4L3
# LOC100859381 LOC100859381
# H2AFB2 H2AB2
# TMEM101 TMEM101
# LOC100859393 LOC100859393
# METTL23 METTL23
# GJA9 GJA9-MYCBP
# LOC100859396 LOC100859396
# TRIOBP TRIOBP
# GPR158 GPR158
# ANKK1 ANKK1
# GBA2 GBA2
# MHCIA1 MHCIA1
# LOC100859410 LOC100859410
# KDM3B KDM3B
# UBE2U UBE2U
# UBE2C UBE2C
# LOC100859414 LOC100859414
# IFNAL1 LOC100859414
# LOC100859420 LOC100859420
# LOC100859423 LOC100859423
# TMEM40L TMEM40
# LOC100859427 LOC100859427
# LOC100859429 LOC100859429
# LOC100859430 LOC100859430
# AEBP1 AEBP1
# LOC100859432 LOC100859432
# LOC100859433 LOC100859433
# THNSL1 THNSL1
# EN2 EN2
# En-2 En2
# Gg-En-2 EN2
# LOC100859437 LOC100859437
# SDCBP2 SDCBP2
# C1orf167 C1orf167
# CERS2 CERS2
# GPATCH4 GPATCH4
# LOC100859449 LOC100859449
# LOC100859453 LOC100859453
# LOC100859454 LOC100859454
# LOC100859455 LOC100859455
# LOC100859456 LOC100859456
# LOC100859458 LOC100859458
# LOC100859459 LOC100859459
# LOC100859462 LOC100859462
# LOC100859466 LOC100859466
# LOC100859467 LOC100859467
# LOC100859468 LOC100859468
# SLAINL LOC100859468
# ZNF3L1 ZNF3L1
# LOC100859471 LOC100859471
# LOC100859478 LOC100859478
# LOC100859481 LOC100859481
# LOC100859484 LOC100859484
# TMED4 TMED4
# LOC100859486 LOC100859486
# OR14A16L16 OR14A16L16
# ZNF420 ZNF420
# CEP126 CEP126
# KIAA1377 CEP126
# LOC100859491 LOC100859491
# LOC100859492 LOC100859492
# CTXN2 CTXN2
# ZNF606 ZNF606
# ZNF606L ZNF606
# LOC100859500 LOC100859500
# LOC100859501 LOC100859501
# LOC100859502 LOC100859502
# LOC100859508 LOC100859508
# PLTGP6L5 LOC100859508
# LOC100859509 LOC100859509
# LOC100859511 LOC100859511
# MROH7L5 MROH7L5
# NRGN NRGN
# LOC100859518 LOC100859518
# NR2F1 NR2F1
# COUP-TFI NR2F1
# NR2F1A NR2F1
# TCFCOUP1 NR2F1
# OR14A16L8 OR14A16L8
# OR14J1L109 OR14J1L109
# C10orf67 C10orf67
# BTN3A3L2 BTN3A3L2
# BG11 BTN3A3L2
# LOC100859532 LOC100859532
# LOC100859533 LOC100859533
# LOC100859537 LOC100859537
# SYCE2 SYCE2
# C5orf47 C5orf47
# C13H5orf47 C5orf47
# LOC100859549 LOC100859549
# LOC100859551 LOC100859551
# IGBP1L IGBP1L
# CLAPS2 AP2S1
# AP17 AP2S1
# FBH3 AP2S1
# FBHOk AP2S1
# HHC3 AP2S1
# sigma2-adaptin CLAPS2
# OR14J1L43 OR14J1L43
# ALX3 ALX3
# EMALP EMALP
# LOC100859564 LOC100859564
# LOC100859565 LOC100859565
# FAAH2 FAAH2
# MCHR1 MCHR1
# MCHR4 MCHR1
# HM13 HM13
# LOC100859576 LOC100859576
# IGSF1L5 LOC100859576
# P4HTM P4HTM
# GAS2L1 GAS2L1
# TBC1D13L TBC1D13L
# LOC100859586 LOC100859586
# LOC100859587 LOC100859587
# LOC100859589 LOC100859589
# OR14J1L44 OR14J1L44
# LOC100859592 LOC100859592
# RBM15 RBM15
# LOC100859597 LOC100859597
# OR4S2 OR4S2
# C3orf33 C3orf33
# C9H3orf33 C3orf33
# LOC100859602 LOC100859602
# TRPM6 TRPM6
# FARSA FARSA
# FARSLA FARSA
# PheRS FARS2
# MPZ MPZ
# MPP MPHOSPH6
# SRSF7 SRSF7
# CREB3L1 CREB3L1
# LOC100859611 LOC100859611
# EMID1 EMID1
# PELP1 PELP1
# LOC100859615 LOC100859615
# LOC100859616 LOC100859616
# LOC100859620 LOC100859620
# TARM1L2 LOC100859620
# AGRPL AGRPL
# LOC100859623 LOC100859623
# LOC100859624 LOC100859624
# LOC100859625 LOC100859625
# LOC100859628 LOC100859628
# MR1 PNKD
# LOC100859629 LOC100859629
# HH3L LOC100859629
# RP11-298I3.5 RP11-298I3.5
# LOC100859631 LOC100859631
# AGWCL LOC100859631
# PGAP2 PGAP2
# DISC1 DISC1
# LOC100859636 LOC100859636
# MYO7L1 MYO7L1
# LOC100859640 LOC100859640
# SDHC LOC642502
# LOC100859643 LOC100859643
# LOC100859645 LOC100859645
# GSTAL LOC100859645
# GSTAL2 LOC100859645
# CCDC96 CCDC96
# LOC100859648 LOC100859648
# PFKFB4 PFKFB4
# PITPNC1 PITPNC1
# LOC100859657 LOC100859657
# LOC100859660 LOC100859660
# AAAS AAAS
# aladin AAAS
# LOC100859662 LOC100859662
# OR14J1L107 OR14J1L107
# LOC100859665 LOC100859665
# C2orf50 C2orf50
# C3H2orf50 C2orf50
# LOC100859672 LOC100859672
# CLC2EL1 CLC2EL1
# PCBP4 PCBP4
# LOC100859675 LOC100859675
# LMAN2 LMAN2
# LOC100859679 LOC100859679
# LOC100859680 LOC100859680
# CFAP126 CFAP126
# LOC100859682 LOC100859682
# PLTGP6L4 LOC100859682
# LOC100859683 LOC100859683
# LOC100859688 LOC100859688
# LOC100859690 LOC100859690
# LOC100859691 LOC100859691
# LOC100859692 LOC100859692
# DLGAP1L DLGAP1L
# LOC100859694 LOC100859694
# LOC100859695 LOC100859695
# LOC100859696 LOC100859696
# SNRKL LOC100859696
# TMEM72 TMEM72
# RSPH10B RSPH10B
# RSPH10B2 RSPH10B2
# LOC100859703 LOC100859703
# HCN3 HCN3
# ZNF551L1 ZNF551L1
# LOC100859706 LOC100859706
# IGSF1L4 LOC100859706
# IL2RB IL2RB
# CD122 IL2RB
# LOC100859709 LOC100859709
# LOC100859713 LOC100859713
# LOC100859715 LOC100859715
# RFC5 RFC5
# SDHB SDHB
# ip SDHB
# APOC3 APOC3
# LOC100859722 LOC100859722
# PI4KB PI4KB
# PIK4CB PI4KB
# LOC100859725 LOC100859725
# IGSF1L8 LOC100859725
# LOC100859726 LOC100859726
# SDR9C7 SDR9C7
# OR14J1L45 OR14J1L45
# LOC100859732 LOC100859732
# CIDEC CIDEC
# CLC2BL3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-663eaf778061> in <module>
#       1 for k, v in s.items():
#       2     if k not in s2 or s2[k] != v:
# ----> 3         print(k, v)
#
# ~/Projects/Environments/harmonizome/lib/python3.8/site-packages/ipykernel/iostream.py in write(self, string)
#     402             is_child = (not self._is_master_process())
#     403             # only touch the buffer in the IO thread to avoid races
# --> 404             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     405             if is_child:
#     406                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# ~/Projects/Environments/harmonizome/lib/python3.8/site-packages/ipykernel/iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# ~/Projects/Environments/harmonizome/lib/python3.8/site-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     398                                  copy_threshold=self.copy_threshold)
#     399             data.group = group
# --> 400         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     401
#     402     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~/Projects/Environments/harmonizome/lib/python3.8/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
